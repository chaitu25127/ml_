# %%
from sklearn.datasets import load_diabetes
import pandas as pd

data=load_diabetes()

df = pd.DataFrame(data.data,columns = data.feature_names)
df["target"]=data.target

df.head()
x = df.drop("target",axis=1)
y=df["target"]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# -> linear Regression has linear model
from sklearn.linear_model import Ridge
model = Ridge(alpha = 0.1)
model.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=0.1)

# %%
print(f"{model.score(xtest,ytest)*100:.0f}%")
# Out:
# 46%

# %%
model.coef_
# Out:
# array([  42.85566976, -205.49431899,  505.08903304,  317.0932049 ,
#        -108.50026183,  -86.23673333, -190.36318008,  151.70708637,
#         392.28931896,   79.9081772 ])

# %%
from sklearn.linear_model import Lasso
model = Lasso (alpha = 0.1)
model.fit(x,y)
# Out:
# Lasso(alpha=0.1)

# %%
print(f"{model.score(xtest,ytest)*100:.0f}%")
# Out:
# 48%

# %%
model.coef_
# Out:
# array([  -0.        , -155.3599757 ,  517.18679544,  275.07723537,
#         -52.53936509,   -0.        , -210.1579914 ,    0.        ,
#         483.91264753,   33.67396468])

# %%
from sklearn.linear_model import ElasticNet
# l1_ratio says how much we are using lasso in elasticnet (50%) 
model= ElasticNet(alpha=0.1,l1_ratio=0.5)
model.fit(x,y)
# Out:
# ElasticNet(alpha=0.1)

# %%
print(f"{model.score(xtest,ytest)*100:.0f}%")
# Out:
# 10%

# %%
model.coef_
# Out:
# array([ 10.28633208,   0.28598338,  37.46465473,  27.54476518,
#         11.10885591,   8.3558916 , -24.12080871,  25.50549197,
#         35.46569979,  22.89498509])

# %%
ypred=model.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
print(np.sqrt(mean_squared_error(ytest,ypred)))
# Out:
# 69.01308441185304
